# %% [markdown]
# In this  we will going to clean data of students  raw data

# %%
# !pip install numpy

# %%
import numpy as np
import pandas as pd
data=pd.read_csv("messy_students_1000.csv")
d_copy=data.copy()
d_copy
# Out:
#       Student_ID            Name   Age  Gender Attendance   Python   DSA  \
# 0           1528    Arjun Mishra  19.0  Female       45.0     74.0  81.0
# 1           1360     Tanya Gupta  20.0    Male       86.4     49.0  86.0
# 2           1448  Ishita Agarwal  20.0  Female       77.6     69.0  76.0
# 3           1032     Vivek Singh  18.0  Female       74.3     62.0  76.0
# 4           1622     Yash Mishra  19.0  Female       91.2     66.0  67.0
# ...          ...             ...   ...     ...        ...      ...   ...
# 1020        1701    Simran Yadav  20.0  Female       73.8     62.0  72.0
# 1021        1072   Pooja Chauhan  20.0  Female       87.5     72.0  52.0
# 1022        1107     Rahul Singh  20.0  Female       76.8  unknown  76.0
# 1023        1271    Manish Verma  21.0     NaN       83.8     64.0  29.0
# 1024        1861    Ritik Sharma  21.0    Male       75.0     95.0  67.0
#
#        DBMS Maths     OS  Projects  Internships  Backlogs  CGPA Placed  \
# ...

# %%
d_copy.drop_duplicates(inplace=True)
d_copy.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Student_ID      1025 non-null   int64
#  1   Name            1017 non-null   str
#  2   Age             1020 non-null   float64
#  3   Gender          1010 non-null   str
#  4   Attendance      1014 non-null   str
#  5   Python          1016 non-null   str
#  6   DSA             1002 non-null   str
#  7   DBMS            1008 non-null   str
#  8   Maths           1011 non-null   str
#  9   OS              1003 non-null   str
#  10  Projects        1012 non-null   float64
#  11  Internships     1011 non-null   float64
#  12  Backlogs        1018 non-null   float64
#  13  CGPA            1006 non-null   str
#  14  Placed          1013 non-null   str
#  15  Admission_Date  1006 non-null   str

# %%
d_copy["Attendance"]=pd.to_numeric(d_copy["Attendance"], errors="coerce").astype("float64")
a=d_copy["Attendance"].mean()
d_copy["Attendance"]=d_copy["Attendance"].fillna(a)
d_copy["Attendance"].isnull().sum()
# Out:
# np.int64(0)

# %%
d_copy.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1000 entries, 0 to 1024
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student_ID      1000 non-null   int64
#  1   Name            992 non-null    str
#  2   Age             995 non-null    float64
#  3   Gender          985 non-null    str
#  4   Attendance      1000 non-null   float64
#  5   Python          992 non-null    str
#  6   DSA             978 non-null    str
#  7   DBMS            986 non-null    str
#  8   Maths           987 non-null    str
#  9   OS              979 non-null    str
#  10  Projects        987 non-null    float64
#  11  Internships     987 non-null    float64
#  12  Backlogs        993 non-null    float64
#  13  CGPA            981 non-null    str
#  14  Placed          988 non-null    str
#  15  Admission_Date  982 non-null    str
# dtypes: float64(5), int64(1), str(10)
# memory usage: 132.8 KB
